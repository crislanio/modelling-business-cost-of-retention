# %% [markdown]
# # This is an example notebook
#
# We are just proving that the environment is working

# %%
import sys

print(sys.executable)
# Out:
# /Users/eoinmurray/opt/anaconda3/envs/dev/bin/python

# %%
import numpy

print(numpy.__version__)
# Out:
# 1.18.1

# %%
import matplotlib
import matplotlib.pyplot as plt

# I'm using a 4k screen - so this increases the matplotlib resolution
# %config InlineBackend.figure_format = 'retina'

print(matplotlib.__version__)
# Out:
# 3.2.1

# %%
plt.plot([1, 2, 3])
